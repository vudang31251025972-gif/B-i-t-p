# %% [markdown]
# <a href="https://colab.research.google.com/github/vudang31251025972-gif/B-i-t-p/blob/main/23.5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import folium
nha_kho = {"Kho A": [10.7565468,106.665875], "Kho B": [10.773389071422123, 106.70117186824456], "Kho C": [10.815804844208422, 106.66420072883588],
}
m = folium.Map(location=[10.7565468,106.665875], zoom_start=13)
folium.Marker(nha_kho['Kho A'], popup='BV Truyền Máu Huyết Học', icon=folium.Icon(color="green")).add_to(m)
folium.Circle(nha_kho['Kho A'], radius=3000, color="blue", fill=True, fill_opacity=0.1).add_to(m)
folium.Marker(nha_kho['Kho B'], popup='SaiGon center', icon=folium.Icon(color="green")).add_to(m)
folium.Circle(nha_kho['Kho B'], radius=5000, color="blue", fill=True, fill_opacity=0.1).add_to(m)
folium.Marker(nha_kho['Kho C'], popup='Sân bay Tân Sơn Nhất', icon=folium.Icon(color="green")).add_to(m)
folium.Circle(nha_kho['Kho C'], radius=10000, color="blue", fill=True, fill_opacity=0.1).add_to(m)
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88f9e5e7977bbc73ef4d66464e692644 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88f9e5e7977bbc73ef4d66464e692644&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_88f9e5e7977bbc73ef4d66464e692644 = L.map(
#                 &quot;map_88f9e5e7977bbc73ef4d66464e692644&quot;,
#                 {
#                     center: [10.7565468, 106.665875],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a0422ff454a988ae1b5828b51d355074 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a0422ff454a988ae1b5828b51d355074.addTo(map_88f9e5e7977bbc73ef4d66464e692644);
#
#
#             var marker_f3dee6fbd65dcda870dd963d719df5c0 = L.marker(
#                 [10.7565468, 106.665875],
#                 {
# }
#             ).addTo(map_88f9e5e7977bbc73ef4d66464e692644);
#
#
#             var icon_4faab9a8b176e3345c066ba29ed1b1bf = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_750de316dcfb8e50c2b5a24beb290bae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4eed94848bf12f4e50cd1c433fbd00cb = $(`&lt;div id=&quot;html_4eed94848bf12f4e50cd1c433fbd00cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;BV Truyền Máu Huyết Học&lt;/div&gt;`)[0];
#                 popup_750de316dcfb8e50c2b5a24beb290bae.setContent(html_4eed94848bf12f4e50cd1c433fbd00cb);
#
#
#
#         marker_f3dee6fbd65dcda870dd963d719df5c0.bindPopup(popup_750de316dcfb8e50c2b5a24beb290bae)
#         ;
#
#
#
#
#                 marker_f3dee6fbd65dcda870dd963d719df5c0.setIcon(icon_4faab9a8b176e3345c066ba29ed1b1bf);
#
#
#             var circle_491cbe8a88fc96960990f2cd04b877e1 = L.circle(
#                 [10.7565468, 106.665875],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 3000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_88f9e5e7977bbc73ef4d66464e692644);
#
#
#             var marker_191a1b5a6e0d2c8bd9d01608b068a9f3 = L.marker(
#                 [10.773389071422123, 106.70117186824456],
#                 {
# }
#             ).addTo(map_88f9e5e7977bbc73ef4d66464e692644);
#
#
#             var icon_e18b70689ea7340a5b9b48b786472f15 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;info-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_a8e83e82ee4d0c6c3acafaa2e7957998 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d19859cc869a2af4a33a901442008f0d = $(`&lt;div id=&quot;html_d19859cc869a2af4a33a901442008f0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;SaiGon center&lt;/div&gt;`)[0];
#                 popup_a8e83e82ee4d0c6c3acafaa2e7957998.setContent(html_d19859cc869a2af4a33a901442008f0d);
#
#
#
#         marker_191a1b5a6e0d2c8bd9d01608b068a9f3.bindPopup(popup_a8e83e82ee4d0c6c3acafaa2e7957998)
#         ;
#
#
#
#
#                 marker_191a1b5a6e0d2c8bd9d01608b068a9f3.setIcon(icon_e18b70689ea7340a5b9b48b786472f15);
#
#
#             var circle_d1672f03ff0535586c6f77c81c58e7b2 = L.circle(
#                 [10.773389071422123, 106.70117186824456],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.1, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5000, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_88f9e5e7977
